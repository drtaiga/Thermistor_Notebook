# %%
# %config InlineBackend.figure_format = 'svg'
from NB_Setup import *
# %matplotlib inline

# %% [markdown]
# # Thermistors
#
# $$ R(T) = R_* \exp \left[ B \left(  \frac{1}{T} - \frac{1}{T_*} \right)  \right] \$$

# %%
thermres_plot()

# %% [markdown]
# # Voltage Divider Circuits

# %% [markdown]
# ## Generic Divider Circuits

# %%
draw_dividers()

# %% [markdown]
# $$V^{(1A)} = V_o \left[ \frac{R_1}{R_0 + R_1} \right] \qquad \qquad V^{(1B)} =  V_o \left[ \frac{R_0}{R_0 + R_1} \right] \tag{1}\label{eq1}$$
#
# in \ref{eq1}

# %%
draw_dividers2()

# %% [markdown]
# $$V^{(2A)} = V_o \left[ \frac{R(T)}{R_0 + R(T)} \right] \qquad \qquad V^{(2B)} =  V_o \left[ \frac{R_0}{R_0 + R(T)} \right] \tag{1}\label{eq1}$$

# %%
divider_plot()
# Out:
# interactive(children=(IntSlider(value=17900, description='\\(R_0 (\\Omega) \\)', max=100000, min=5000, step=50…
# <function NB_Setup.div_plot(R0)>

# %%
draw_bridge()

# %% [markdown]
# $$\Delta V^{(3A)} = V^{(3A)}_T - V^{(3A)}_B = V_0 \left[ \frac{1}{1 + \rho} - \frac{R(T)}{R_0 + R(T)} \right] $$
#
# and
#
# $$\Delta V^{(3B)} = V^{(3B)}_T - V^{(3B)}_B = V_0 \left[ \frac{1}{1 + \rho} - \frac{R_0}{R_0 + R(T)} \right].$$
#
# ... the effects of two resistors in the upper bridge are encapsulated by the resistor ratio $\rho = R_1/R_3$.

# %%
bridge_plot2()
# Out:
# interactive(children=(IntSlider(value=17500, description='\\(R_0 (\\Omega) \\)', max=100000, min=5000, step=10…
# <function NB_Setup.br_plot(R0, RHO)>

# %% [markdown]
# ## Thermistor Divider Circuits

# %%
draw_divamp()

# %% [markdown]
# $$V = V_o \left[ \frac{R_0}{R_0 + R(T)} \right] \times A_G + V_{\it{ref}}
# \tag{1}$$

# %% [markdown]
# with the $A_G$ is the amplifier gain and $V_{\it ref}$ is a reference voltage that provides an offset for the amplified signal. The amplifier in figure -- is an instrumentation aplifier rather than an ordinary op-amp. ...

# %%
draw_bridgeamp()

# %% [markdown]
# # Bridge Circuits

# %% [markdown]
# ## Generic Wheatstone Bridge Circuits

# %%
ampcircuits_plot()
# Out:
# interactive(children=(IntSlider(value=17500, description='\\(R_0 (\\Omega) \\)', max=100000, min=5000, step=10…
# <function NB_Setup.amp_plot(R0, V_ref, RHO, A_G)>

# %% [markdown]
# # Appendix:

# %% [markdown]
# ## Inflection point

# %%
# %load_ext watermark

# %%
# %watermark -iv -p watermark
# %watermark -u -n -t -z
#%watermark?
# Out:
# watermark: 2.1.0
#
# scipy     : 1.5.2
# ipywidgets: 7.5.1
# matplotlib: 3.3.2
# schemdraw : 0.8
# numpy     : 1.19.2
#
# Last updated: Thu Dec 10 2020 22:40:59EST
